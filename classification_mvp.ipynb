# %% [markdown]
# #MVP
#
# The goal of this project is to predict credit card transactions as real or fraudulent based on a variety of features. I will use several classification tehcniques and compare models. Below is a confusion matrix obtained from a logistic regression model.
#
# The dataset is extremely unbalanced with less than 1% of transactions being fraudulent. Seeing as there are probably high costs to reversing transactions and customer discontent, I hope to imporve on these results with further modeling.

# %%
#Confusion matrix
